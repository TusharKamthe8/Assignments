# %%
# Question No-1

# %%
""" As Exception class is a superclass it autmatical includes all errors which may occur. When we create a custom exception we inherit
    this superclass into our new class which makes the new class inherit all the exception inluding the ones we have defined customly. 
    This will also help in upcoming code as we can simply use this new class rather than the Exception class in order to clear exceptions
    more accurately including the ones that we have defined. """
# Out:
# ' As Exception class is a superclass it autmatical includes all errors which may occur. When we create a custom exception we inherit\n    this superclass into our new class which makes the new class inherit all the exception inluding the ones we have defined customly. \n    This will also help in upcoming code as we can simply use this new class rather than the Exception class in order to clear exceptions\n    more accurately including the ones that we have defined. '

# %%
# Question No-2

# %%
import inspect as ipt  
def tree(self, a = 0):  
    print ('_' * a, self.__name__)  
    for i in self.__subclasses__():  
        tree(i, a + 3)  
print ("The Hierarchy for inbuilt exceptions is: ")    
ipt.getclasstree(ipt.getmro(Exception))  
tree(Exception)
# Out:
# The Hierarchy for inbuilt exceptions is:
#  Exception
# ___ TypeError
# ______ FloatOperation
# ______ MultipartConversionError
# ___ StopAsyncIteration
# ___ StopIteration
# ___ ImportError
# ______ ModuleNotFoundError
# ______ ZipImportError
# ___ OSError
# ______ ConnectionError
# _________ BrokenPipeError
# _________ ConnectionAbortedError
# _________ ConnectionRefusedError
# _________ ConnectionResetError
# ____________ RemoteDisconnected
# ______ BlockingIOError
# ______ ChildProcessError
# ______ FileExistsError
# ______ FileNotFoundError
# ______ IsADirectoryError
# ______ NotADirectoryError
# ______ InterruptedError
# _________ InterruptedSystemCall
# ______ PermissionError
# ______ ProcessLookupError
# ______ TimeoutError
# ______ UnsupportedOperation
# ______ itimer_error
# ______ herror
# ______ gaierror
# ______ SSLError
# _________ SSLCertVerificationError
# _________ SSLZeroReturnError
# _________ SSLWantWriteError
# _________ SSLWantReadError
# ...

# %%
# Question No-3

# %%
""" ArithmeticError consits of errors such as 
    1)FloatingPointError
    2)OverflowError
    3)ZeroDivisionError
    
    1)FloatingPointError- It is a error faced while handling floating point numbers in pyhton. Fixed number of binary didgits are used
                        to represent decimal number, as it is difficult to represent some decimal number in binary which leads to small
                        roundoff errors.
    2)OverflowError- When we try to get a very large number as a result of some code then overflow error occurs. 
    3)ZeroDivisionError- This error is raised when any integer is divided by zero. """

# Example ZeroDivisionError: In below code we are diving 10 by zero which is infinty in mathematical terms but python condsiders it as an error.
import math
try:
    print(10/0)
except ZeroDivisionError as e:
          print("Error:",e.__class__)
    

# Example 2)- When we try to getsummed value of powers of 5 from 1 to 1000 we get a overfloe error due to calculation of such large value.
a = 5.0
try:
    for i in range(1,1000):
        a = a ** i
except OverflowError as e:
    print("Error:",e.__class__)
# Out:
# Error: <class 'ZeroDivisionError'>
# Error: <class 'OverflowError'>

# %%
# Question No-4

# %%
""" LookupError class is used when a value or index is not found. It has primarily two subclasses KeyError and IndexError. """
# KeyError Example- Here the code is written to ask for a key from user so that it can match it in the dictonary and give output. If not matched KeyError occurs.
student = {'Name':'Manan', 'Age': 28, 'Language': 'Python'}
a = input("Information Required:")

try:
    print(a,"is",student[a])
except LookupError as e:
    print("Error:",e.__class__)

# IndexError Example- Here index given is much higher than number of elemwwents in the given list hence IndexErros is thrown.
lisst = [1,2,3,4,5,6]
try:
    print(lisst[11])
except LookupError as e:
    print("Error:",e.__class__)
# Out:
# Information Required: standard
# Error: <class 'KeyError'>
# Error: <class 'IndexError'>

# %%
# Question No-5

# %%
""" ImportError- ImportError is raised when a module or member of module cannot be imported. 
    ModuleNotFoundError- This is the subclass of ImportError which is raised by import when a module could not be found. It is also raised 
    when None is found in sys.modules. """

# Example ImportError-
try:
    from time import myexception
except ImportError as e:
    print("Error:",e.__class__)
    
# Example ModuleNotFoundError-
try:
    import myexception
except ModuleNotFoundError as e:
    print("Error:",e.__class__)
# Out:
# Error: <class 'ImportError'>
# Error: <class 'ModuleNotFoundError'>

# %%
# Question No-6

# %%
"""
    1)Use specific exception and avoid a generic one like 'Exception' superclass.
    2)Print a proper message while addressing a error.
    3)Always log errors as it is a best practice for neat and clean code,
    4)Never use multiple exception handling always be specific for exceptions.
    5)Clean up all the resources which were accessed while performing the code. """
# Out:
# "\n    1)Use specific exception and avoid a generic one like 'Exception' superclass.\n    2)Print a proper message while addressing a error.\n    3)Always log errors as it is a best practice for neat and clean code,\n    4)Never use multiple exception handling always be specific for exceptions.\n    5)Clean up all the resources which were accessed while performing the code. "
